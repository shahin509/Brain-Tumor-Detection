# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint,TensorBoard,LambdaCallback
from keras.layers import SeparableConv2D
from keras.layers import Input,Dropout, Dense,GlobalAvgPool2D, GlobalAveragePooling2D,Conv2D, ZeroPadding2D, BatchNormalization, Activation, MaxPooling2D, Flatten, AvgPool2D, Concatenate, MaxPool2D
from keras.models import Sequential,Model
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU
from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot
import pandas as pd

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tqdm import tqdm
import seaborn as sns
import numpy as np
import itertools
import time
import datetime
import os
import cv2
import io

import imutils
import matplotlib.pyplot as plt
from os import listdir

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

from sklearn.cluster import KMeans

# %matplotlib inline

# %%
# Set the path to the dataset
# dataset_path = "C:/Users/USER/ML/Latest/def_data"
dataset_path = "/content/gdrive/MyDrive/Google Colab"

# Define the training and testing directories
train_dir = os.path.join(dataset_path, "/content/gdrive/MyDrive/Google Colab/Training")
test_dir = os.path.join(dataset_path, "/content/gdrive/MyDrive/Google Colab/Testing")

# Define the categories
categories = ["glioma", "meningioma", "notumor", "pituitary"]

# %%
# Load and preprocess the dataset
train_data = []
for category in categories:
    folder_path = os.path.join(train_dir, category)
    images = os.listdir(folder_path)
    count = len(images)
    print(count)
    train_data.append(pd.DataFrame({"Image": images, "Category": [category] * count, "Count": [count] * count}))

train_df = pd.concat(train_data, ignore_index=True)

# Visualize the distribution of tumor types in the training dataset
plt.figure(figsize=(8, 6))
sns.barplot(data=train_df, x="Category", y="Count", palette = "Blues", legend=False)
plt.title("Distribution of Tumor Types")
plt.xlabel("Tumor Type")
plt.ylabel("Count")
plt.show()
# Out:
# 1321
# 1339
# 1595
# 1457
# <ipython-input-4-34d7eaa87feb>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=train_df, x="Category", y="Count", palette = "Blues", legend=False)

# %%
# Load and preprocess the dataset
test_data = []
for category in categories:
    folder_path = os.path.join(test_dir, category)
    images = os.listdir(folder_path)
    count = len(images)
    print(count)
    test_data.append(pd.DataFrame({"Image": images, "Category": [category] * count, "Count": [count] * count}))

test_df = pd.concat(test_data, ignore_index=True)

# Visualize the distribution of tumor types in the training dataset
plt.figure(figsize=(8, 6))
sns.barplot(data=test_df, x="Category", y="Count", palette = "Blues")
plt.title("Distribution of Tumor Types")
plt.xlabel("Tumor Type")
plt.ylabel("Count")
plt.show()
# Out:
# 300
# 306
# 405
# 300
# <ipython-input-5-691c079eace0>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=test_df, x="Category", y="Count", palette = "Blues")

# %%
# Visualize sample images for each tumor type
plt.figure(figsize=(12, 8))
for i, category in enumerate(categories):
    folder_path = os.path.join(train_dir, category)
    image_path = os.path.join(folder_path, os.listdir(folder_path)[0])
    img = plt.imread(image_path)
    plt.subplot(2, 2, i+1)
    plt.imshow(img)
    plt.title(category)
    plt.axis("on")
plt.tight_layout()
plt.show()

# %%
# Set the image size
image_size = (150, 150)

# Set the batch size for training
batch_size = 32

# Set the number of epochs for training
epochs = 50

# %%
# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode="nearest"
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical"
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
# # Define the model architecture
# model = Sequential([
#     Conv2D(32, (3, 3), activation="relu", input_shape=(image_size[0], image_size[1], 3)),
#     MaxPooling2D((2, 2)),
#     Conv2D(64, (3, 3), activation="relu"),
#     MaxPooling2D((2, 2)),
#     Conv2D(128, (3, 3), activation="relu"),
#     MaxPooling2D((2, 2)),
#     Conv2D(128, (3, 3), activation="relu"),
#     MaxPooling2D((2, 2)),
#     Flatten(),
#     Dense(512, activation="relu"),
#     Dropout(0.5),
#     Dense(len(categories), activation="softmax")
# ])

# # Compile the model
# model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
def resnet(input_shape, n_classes):

  def conv_bn_rl(x, f, k=1, s=1, p='same'):
    x = Conv2D(f, k, strides=s, padding=p)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x


  def identity_block(tensor, f):
    x = conv_bn_rl(tensor, f)
    x = conv_bn_rl(x, f, 3)
    x = Conv2D(4*f, 1)(x)
    x = BatchNormalization()(x)

    x = Add()([x, tensor])
    output = ReLU()(x)
    return output


  def conv_block(tensor, f, s):
    x = conv_bn_rl(tensor, f)
    x = conv_bn_rl(x, f, 3, s)
    x = Conv2D(4*f, 1)(x)
    x = BatchNormalization()(x)

    shortcut = Conv2D(4*f, 1, strides=s)(tensor)
    shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    output = ReLU()(x)
    return output


  def resnet_block(x, f, r, s=2):
    x = conv_block(x, f, s)
    for _ in range(r-1):
      x = identity_block(x, f)
    return x


  input = Input(input_shape)

  x = conv_bn_rl(input, 64, 7, 2)
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = resnet_block(x, 64, 3, 1)
  x = resnet_block(x, 128, 4)
  x = resnet_block(x, 256, 6)
  x = resnet_block(x, 512, 3)

  x = GlobalAvgPool2D()(x)

  output = Dense(n_classes, activation='softmax')(x)

  model = Model(input, output)
  return model

# %%
IMG_SHAPE = (150, 150, 3)

# %%
model = resnet(IMG_SHAPE, 4)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 75, 75, 64)           9472      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 75, 75, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 75, 75, 64)           0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 38, 38, 64)           0         ['re_lu[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 38, 38, 64)           4160      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 38, 38, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 38, 38, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 64)           36928     ['re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 38, 38, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 38, 38, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 38, 38, 256)          16640     ['re_lu_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 38, 38, 256)          16640     ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 38, 38, 256)          1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 38, 38, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 38, 38, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  re_lu_3 (ReLU)              (None, 38, 38, 256)          0         ['add[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 38, 38, 64)           16448     ['re_lu_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 38, 38, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 38, 38, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 38, 38, 64)           36928     ['re_lu_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 38, 38, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 38, 38, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 38, 38, 256)          16640     ['re_lu_5[0][0]']
#
#  batch_normalization_7 (Bat  (None, 38, 38, 256)          1024      ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 38, 38, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 're_lu_3[0][0]']
#
#  re_lu_6 (ReLU)              (None, 38, 38, 256)          0         ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 38, 38, 64)           16448     ['re_lu_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 38, 38, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 38, 38, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 38, 38, 64)           36928     ['re_lu_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 38, 38, 64)           256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 38, 38, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 38, 38, 256)          16640     ['re_lu_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 38, 38, 256)          1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 38, 38, 256)          0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      're_lu_6[0][0]']
#
#  re_lu_9 (ReLU)              (None, 38, 38, 256)          0         ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 38, 38, 128)          32896     ['re_lu_9[0][0]']
#
#  batch_normalization_11 (Ba  (None, 38, 38, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 38, 38, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 19, 19, 128)          147584    ['re_lu_10[0][0]']
#
#  batch_normalization_12 (Ba  (None, 19, 19, 128)          512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 19, 19, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 19, 19, 512)          66048     ['re_lu_11[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 19, 19, 512)          131584    ['re_lu_9[0][0]']
#
#  batch_normalization_13 (Ba  (None, 19, 19, 512)          2048      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 19, 19, 512)          2048      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 19, 19, 512)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  re_lu_12 (ReLU)             (None, 19, 19, 512)          0         ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 19, 19, 128)          65664     ['re_lu_12[0][0]']
#
#  batch_normalization_15 (Ba  (None, 19, 19, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 19, 19, 128)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 19, 19, 128)          147584    ['re_lu_13[0][0]']
#
#  batch_normalization_16 (Ba  (None, 19, 19, 128)          512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 19, 19, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 19, 19, 512)          66048     ['re_lu_14[0][0]']
#
#  batch_normalization_17 (Ba  (None, 19, 19, 512)          2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 19, 19, 512)          0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      're_lu_12[0][0]']
#
#  re_lu_15 (ReLU)             (None, 19, 19, 512)          0         ['add_4[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 19, 19, 128)          65664     ['re_lu_15[0][0]']
#
#  batch_normalization_18 (Ba  (None, 19, 19, 128)          512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 19, 19, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 19, 19, 128)          147584    ['re_lu_16[0][0]']
#
#  batch_normalization_19 (Ba  (None, 19, 19, 128)          512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 19, 19, 128)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 19, 19, 512)          66048     ['re_lu_17[0][0]']
#
#  batch_normalization_20 (Ba  (None, 19, 19, 512)          2048      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 19, 19, 512)          0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      're_lu_15[0][0]']
#
#  re_lu_18 (ReLU)             (None, 19, 19, 512)          0         ['add_5[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 19, 19, 128)          65664     ['re_lu_18[0][0]']
#
#  batch_normalization_21 (Ba  (None, 19, 19, 128)          512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  re_lu_19 (ReLU)             (None, 19, 19, 128)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 19, 19, 128)          147584    ['re_lu_19[0][0]']
#
#  batch_normalization_22 (Ba  (None, 19, 19, 128)          512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 19, 19, 128)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 19, 19, 512)          66048     ['re_lu_20[0][0]']
#
#  batch_normalization_23 (Ba  (None, 19, 19, 512)          2048      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 19, 19, 512)          0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      're_lu_18[0][0]']
#
#  re_lu_21 (ReLU)             (None, 19, 19, 512)          0         ['add_6[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 19, 19, 256)          131328    ['re_lu_21[0][0]']
#
#  batch_normalization_24 (Ba  (None, 19, 19, 256)          1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 19, 19, 256)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 10, 10, 256)          590080    ['re_lu_22[0][0]']
#
#  batch_normalization_25 (Ba  (None, 10, 10, 256)          1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 10, 10, 1024)         263168    ['re_lu_23[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 10, 10, 1024)         525312    ['re_lu_21[0][0]']
#
#  batch_normalization_26 (Ba  (None, 10, 10, 1024)         4096      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 10, 10, 1024)         4096      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 10, 10, 1024)         0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  re_lu_24 (ReLU)             (None, 10, 10, 1024)         0         ['add_7[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 10, 10, 256)          262400    ['re_lu_24[0][0]']
#
#  batch_normalization_28 (Ba  (None, 10, 10, 256)          1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 10, 10, 256)          590080    ['re_lu_25[0][0]']
#
#  batch_normalization_29 (Ba  (None, 10, 10, 256)          1024      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 10, 10, 1024)         263168    ['re_lu_26[0][0]']
#
#  batch_normalization_30 (Ba  (None, 10, 10, 1024)         4096      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 10, 10, 1024)         0         ['batch_normalization_30[0][0]
#                                                                     ',
#                                                                      're_lu_24[0][0]']
#
#  re_lu_27 (ReLU)             (None, 10, 10, 1024)         0         ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 10, 10, 256)          262400    ['re_lu_27[0][0]']
#
#  batch_normalization_31 (Ba  (None, 10, 10, 256)          1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 10, 10, 256)          590080    ['re_lu_28[0][0]']
#
#  batch_normalization_32 (Ba  (None, 10, 10, 256)          1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 10, 10, 1024)         263168    ['re_lu_29[0][0]']
#
#  batch_normalization_33 (Ba  (None, 10, 10, 1024)         4096      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 10, 10, 1024)         0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      're_lu_27[0][0]']
#
#  re_lu_30 (ReLU)             (None, 10, 10, 1024)         0         ['add_9[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 10, 10, 256)          262400    ['re_lu_30[0][0]']
#
#  batch_normalization_34 (Ba  (None, 10, 10, 256)          1024      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 10, 10, 256)          590080    ['re_lu_31[0][0]']
#
#  batch_normalization_35 (Ba  (None, 10, 10, 256)          1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 10, 10, 1024)         263168    ['re_lu_32[0][0]']
#
#  batch_normalization_36 (Ba  (None, 10, 10, 1024)         4096      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 10, 10, 1024)         0         ['batch_normalization_36[0][0]
#                                                                     ',
#                                                                      're_lu_30[0][0]']
#
#  re_lu_33 (ReLU)             (None, 10, 10, 1024)         0         ['add_10[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 10, 10, 256)          262400    ['re_lu_33[0][0]']
#
#  batch_normalization_37 (Ba  (None, 10, 10, 256)          1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 10, 10, 256)          590080    ['re_lu_34[0][0]']
#
#  batch_normalization_38 (Ba  (None, 10, 10, 256)          1024      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  re_lu_35 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 10, 10, 1024)         263168    ['re_lu_35[0][0]']
#
#  batch_normalization_39 (Ba  (None, 10, 10, 1024)         4096      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 10, 10, 1024)         0         ['batch_normalization_39[0][0]
#                                                                     ',
#                                                                      're_lu_33[0][0]']
#
#  re_lu_36 (ReLU)             (None, 10, 10, 1024)         0         ['add_11[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 10, 10, 256)          262400    ['re_lu_36[0][0]']
#
#  batch_normalization_40 (Ba  (None, 10, 10, 256)          1024      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 10, 10, 256)          590080    ['re_lu_37[0][0]']
#
#  batch_normalization_41 (Ba  (None, 10, 10, 256)          1024      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  re_lu_38 (ReLU)             (None, 10, 10, 256)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 10, 10, 1024)         263168    ['re_lu_38[0][0]']
#
#  batch_normalization_42 (Ba  (None, 10, 10, 1024)         4096      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 10, 10, 1024)         0         ['batch_normalization_42[0][0]
#                                                                     ',
#                                                                      're_lu_36[0][0]']
#
#  re_lu_39 (ReLU)             (None, 10, 10, 1024)         0         ['add_12[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 10, 10, 512)          524800    ['re_lu_39[0][0]']
#
#  batch_normalization_43 (Ba  (None, 10, 10, 512)          2048      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 10, 10, 512)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 5, 5, 512)            2359808   ['re_lu_40[0][0]']
#
#  batch_normalization_44 (Ba  (None, 5, 5, 512)            2048      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 5, 5, 512)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 5, 5, 2048)           1050624   ['re_lu_41[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 5, 5, 2048)           2099200   ['re_lu_39[0][0]']
#
#  batch_normalization_45 (Ba  (None, 5, 5, 2048)           8192      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 5, 5, 2048)           8192      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 5, 5, 2048)           0         ['batch_normalization_45[0][0]
#                                                                     ',
#                                                                      'batch_normalization_46[0][0]
#                                                                     ']
#
#  re_lu_42 (ReLU)             (None, 5, 5, 2048)           0         ['add_13[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 5, 5, 512)            1049088   ['re_lu_42[0][0]']
#
#  batch_normalization_47 (Ba  (None, 5, 5, 512)            2048      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 5, 5, 512)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 5, 5, 512)            2359808   ['re_lu_43[0][0]']
#
#  batch_normalization_48 (Ba  (None, 5, 5, 512)            2048      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  re_lu_44 (ReLU)             (None, 5, 5, 512)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 5, 5, 2048)           1050624   ['re_lu_44[0][0]']
#
#  batch_normalization_49 (Ba  (None, 5, 5, 2048)           8192      ['conv2d_49[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 5, 5, 2048)           0         ['batch_normalization_49[0][0]
#                                                                     ',
#                                                                      're_lu_42[0][0]']
#
#  re_lu_45 (ReLU)             (None, 5, 5, 2048)           0         ['add_14[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 5, 5, 512)            1049088   ['re_lu_45[0][0]']
#
#  batch_normalization_50 (Ba  (None, 5, 5, 512)            2048      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  re_lu_46 (ReLU)             (None, 5, 5, 512)            0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 5, 5, 512)            2359808   ['re_lu_46[0][0]']
#
#  batch_normalization_51 (Ba  (None, 5, 5, 512)            2048      ['conv2d_51[0][0]']
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 5, 5, 512)            0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 5, 5, 2048)           1050624   ['re_lu_47[0][0]']
#
#  batch_normalization_52 (Ba  (None, 5, 5, 2048)           8192      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 5, 5, 2048)           0         ['batch_normalization_52[0][0]
#                                                                     ',
#                                                                      're_lu_45[0][0]']
#
#  re_lu_48 (ReLU)             (None, 5, 5, 2048)           0         ['add_15[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['re_lu_48[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 4)                    8196      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 23595908 (90.01 MB)
# Trainable params: 23542788 (89.81 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size
)
# Out:
# Epoch 1/50
#   1/178 [..............................] - ETA: 1:58:07 - loss: 2.4943 - accuracy: 0.2188

# %%
# Plot the training and validation accuracy over epochs
plt.plot(history.history['accuracy'], '-o')
plt.plot(history.history['val_accuracy'], '-o')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
# Plot the training and validation loss over epochs
plt.plot(history.history['loss'], '-o')
plt.plot(history.history['val_loss'], '-o')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# %%
# Make predictions on the test dataset
predictions = model.predict(test_generator)
predicted_categories = np.argmax(predictions, axis=1)

true_categories = test_generator.classes
print(true_categories)

# Create a confusion matrix
confusion_matrix = tf.math.confusion_matrix(true_categories, predicted_categories)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.tight_layout() #########
plt.xlabel("Predicted")
plt.ylabel("True")
plt.xticks(ticks=np.arange(len(categories)), labels=categories, rotation=45)   ##############
plt.yticks(ticks=np.arange(len(categories)), labels=categories, rotation=45)   ##############
plt.show()

# Plot sample images with their predicted and true labels
test_images = test_generator.filenames
sample_indices = np.random.choice(range(len(test_images)), size=9, replace=False)
print(sample_indices)
sample_images = [test_images[i] for i in sample_indices]
sample_predictions = [categories[predicted_categories[i]] for i in sample_indices]
sample_true_labels = [categories[true_categories[i]] for i in sample_indices]

plt.figure(figsize=(12, 8))
for i in range(9):
    plt.subplot(3, 3, i+1)
    img = plt.imread(os.path.join(test_dir, sample_images[i]))
    plt.imshow(img)
    plt.title(f"Predicted: {sample_predictions[i]}\nTrue: {sample_true_labels[i]}")
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
# Calculate precision, recall, and F1-score from the confusion matrix
precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis=0)
recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis=1)
f1_score = 2 * (precision * recall) / (precision + recall)

# Print precision, recall, and F1-score for each class
for i, category in enumerate(categories):
    print(f"Class: {category}")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1-Score: {f1_score[i]}")
    print()

# Analyze the sample images and their predictions
plt.figure(figsize=(12, 8))
for i in range(9):
    plt.subplot(3, 3, i+1)
    img = plt.imread(os.path.join(test_dir, sample_images[i]))
    plt.imshow(img)
    if sample_predictions[i] == sample_true_labels[i]:
        plt.title(f"Predicted: {sample_predictions[i]}\nTrue: {sample_true_labels[i]}", color='green')
    else:
        plt.title(f"Predicted: {sample_predictions[i]}\nTrue: {sample_true_labels[i]}", color='red')
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
# Save the trained model
model.save("Xception_brain_tumor_detection_model.h5")
